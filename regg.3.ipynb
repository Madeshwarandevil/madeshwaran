# %%
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
ap=pd.read_csv("C:\\Users\\Admin\\Documents\\madeshwaran\\Admission_Predict.csv")

# %%
ap
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
ap.shape
# Out:
# (400, 9)

# %%
ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
adp=ap.drop(['Serial No.','TOEFL Score','GRE Score','SOP','LOR ','CGPA','Research'],axis=1)

# %%
adp
# Out:
#      University Rating  Chance of Admit
# 0                    4              0.92
# 1                    4              0.76
# 2                    3              0.72
# 3                    3              0.80
# 4                    2              0.65
# ..                 ...               ...
# 395                  3              0.82
# 396                  3              0.84
# 397                  4              0.91
# 398                  3              0.67
# 399                  4              0.95
#
# [400 rows x 2 columns]

# %%
x=adp.iloc[:,0].values.reshape(-1,1)
y=adp.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[4],
#        [4],
#        [3],
#        [3],
#        [2],
#        [5],
#        [3],
#        [2],
#        [1],
#        [3],
#        [3],
#        [4],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [4],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [2],
#        [1],
#        [2],
#        [2],
#        [3],
#        [4],
#        [5],
#        [5],
#        [5],
#        [2],
#        [1],
#        [1],
#        [2],
#        [3],
#        [2],
#        [2],
#        [4],
#        [5],
#        [5],
#        [5],
#        [5],
#        [3],
#        [4],
#        [3],
#        [2],
#        [4],
#        [4],
#        [3],
#        [3],
#        [3],
#        [2],
#        [1],
#        [2],
#        [2],
#        [3],
#        [2],
#        [2],
#        [3],
#        [4],
#        [3],
#        [2],
#        [3],
#        [4],
#        [5],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('University Rating')
pt.ylabel('Chance of Admission')
pt.title('linear regression')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_train.shape
# Out:
# (280, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
x_train
# Out:
# array([[2],
#        [2],
#        [5],
#        [2],
#        [1],
#        [5],
#        [5],
#        [2],
#        [3],
#        [2],
#        [4],
#        [2],
#        [3],
#        [1],
#        [4],
#        [2],
#        [4],
#        [3],
#        [3],
#        [3],
#        [4],
#        [3],
#        [2],
#        [3],
#        [3],
#        [2],
#        [2],
#        [4],
#        [5],
#        [3],
#        [3],
#        [5],
#        [3],
#        [3],
#        [5],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [5],
#        [5],
#        [1],
#        [3],
#        [5],
#        [3],
#        [3],
#        [4],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [5],
#        [5],
#        [5],
#        [3],
#        [3],
#        [2],
#        [4],
#        [2],
#        [3],
#        [3],
#        [4],
#        [2],
#        [2],
#        [3],
#        [2],
#        [2],
# ...

# %%
y_train
# Out:
# array([[0.34],
#        [0.71],
#        [0.91],
#        [0.69],
#        [0.47],
#        [0.92],
#        [0.94],
#        [0.71],
#        [0.74],
#        [0.64],
#        [0.93],
#        [0.77],
#        [0.61],
#        [0.6 ],
#        [0.84],
#        [0.64],
#        [0.84],
#        [0.77],
#        [0.63],
#        [0.65],
#        [0.81],
#        [0.84],
#        [0.65],
#        [0.59],
#        [0.7 ],
#        [0.57],
#        [0.7 ],
#        [0.81],
#        [0.88],
#        [0.56],
#        [0.8 ],
#        [0.94],
#        [0.79],
#        [0.62],
#        [0.93],
#        [0.76],
#        [0.78],
#        [0.85],
#        [0.7 ],
#        [0.71],
#        [0.8 ],
#        [0.79],
#        [0.9 ],
#        [0.56],
#        [0.67],
#        [0.94],
#        [0.74],
#        [0.86],
#        [0.76],
#        [0.47],
#        [0.64],
#        [0.81],
#        [0.73],
#        [0.71],
#        [0.73],
#        [0.89],
#        [0.93],
#        [0.86],
# ...

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[0.89699663],
#        [0.80625978],
#        [0.71552293],
#        [0.62478608],
#        [0.71552293],
#        [0.62478608],
#        [0.71552293],
#        [0.71552293],
#        [0.62478608],
#        [0.80625978],
#        [0.53404923],
#        [0.89699663],
#        [0.62478608],
#        [0.53404923],
#        [0.80625978],
#        [0.62478608],
#        [0.53404923],
#        [0.62478608],
#        [0.62478608],
#        [0.71552293],
#        [0.80625978],
#        [0.80625978],
#        [0.80625978],
#        [0.62478608],
#        [0.80625978],
#        [0.71552293],
#        [0.62478608],
#        [0.71552293],
#        [0.89699663],
#        [0.62478608],
#        [0.62478608],
#        [0.71552293],
#        [0.80625978],
#        [0.62478608],
#        [0.80625978],
#        [0.71552293],
#        [0.62478608],
#        [0.80625978],
#        [0.71552293],
#        [0.80625978],
#        [0.71552293],
#        [0.62478608],
#        [0.71552293],
# ...

# %%
comp=pd.DataFrame (x_test,columns=['GRE'])

# %%
comp
# Out:
#      GRE
# 0      5
# 1      4
# 2      3
# 3      2
# 4      3
# ..   ...
# 115    4
# 116    4
# 117    4
# 118    3
# 119    2
#
# [120 rows x 1 columns]

# %%
comp['AVLDATA']=y_test

# %%
comp
# Out:
#      GRE  AVLDATA
# 0      5     0.71
# 1      4     0.70
# 2      3     0.79
# 3      2     0.73
# 4      3     0.72
# ..   ...      ...
# 115    4     0.91
# 116    4     0.90
# 117    4     0.78
# 118    3     0.70
# 119    2     0.59
#
# [120 rows x 2 columns]

# %%
comp['PREDATA']=y_predict

# %%
comp
# Out:
#      GRE  AVLDATA   PREDATA
# 0      5     0.71  0.896997
# 1      4     0.70  0.806260
# 2      3     0.79  0.715523
# 3      2     0.73  0.624786
# 4      3     0.72  0.715523
# ..   ...      ...       ...
# 115    4     0.91  0.806260
# 116    4     0.90  0.806260
# 117    4     0.78  0.806260
# 118    3     0.70  0.715523
# 119    2     0.59  0.624786
#
# [120 rows x 3 columns]

# %%
pt.scatter(x,y,color='blue')
pt.plot(x_test,y_predict,color='red')
pt.xlabel('University Rating')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.010097145539269502

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 0.07565735642177464
