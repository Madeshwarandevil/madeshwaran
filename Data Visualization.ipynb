# %% [markdown]
# # Create data

# %%
movies=['kaththi','sura','master','leo','varisu','thupaki','pokiri']
rating=[8,5,8,10,6,9,8]

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(movies,rating)

# %%
plt.bar(movies,rating)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.plot(movies,rating,linestyle='solid') #solid,dashed,dotted

# %%
plt.plot(movies,rating,linestyle='dashed')

# %%
plt.plot(movies,rating,linestyle='dotted')

# %%
plt.pie(rating,labels=movies)
# Out:
# ([<matplotlib.patches.Wedge at 0x2671d0c0d60>,
# ...
#  [Text(0.9829959026438434, 0.49367910162920176, 'kaththi'),
#   Text(0.37622216034652484, 1.033661881886042, 'sura'),
#   Text(-0.4356877338869098, 1.0100377213453415, 'master'),
#   Text(-1.0925621904163443, 0.12770223205817494, 'leo'),
#   Text(-0.7548658342561114, -0.8001109749733628, 'varisu'),
#   Text(0.1277021809116471, -1.092562196394516, 'thupaki'),
#   Text(0.9829959026438435, -0.4936791016292016, 'pokiri')])

# %% [markdown]
# # sine wave

# %%
import numpy as np

# %%
time=np.arange(0,100,0.5)

# %%
time
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#         5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#        11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ,
#        16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. , 20.5, 21. , 21.5,
#        22. , 22.5, 23. , 23.5, 24. , 24.5, 25. , 25.5, 26. , 26.5, 27. ,
#        27.5, 28. , 28.5, 29. , 29.5, 30. , 30.5, 31. , 31.5, 32. , 32.5,
#        33. , 33.5, 34. , 34.5, 35. , 35.5, 36. , 36.5, 37. , 37.5, 38. ,
#        38.5, 39. , 39.5, 40. , 40.5, 41. , 41.5, 42. , 42.5, 43. , 43.5,
#        44. , 44.5, 45. , 45.5, 46. , 46.5, 47. , 47.5, 48. , 48.5, 49. ,
#        49.5, 50. , 50.5, 51. , 51.5, 52. , 52.5, 53. , 53.5, 54. , 54.5,
#        55. , 55.5, 56. , 56.5, 57. , 57.5, 58. , 58.5, 59. , 59.5, 60. ,
#        60.5, 61. , 61.5, 62. , 62.5, 63. , 63.5, 64. , 64.5, 65. , 65.5,
#        66. , 66.5, 67. , 67.5, 68. , 68.5, 69. , 69.5, 70. , 70.5, 71. ,
# ...

# %%
amplitude=np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.47942554,  0.84147098,  0.99749499,  0.90929743,
#         0.59847214,  0.14112001, -0.35078323, -0.7568025 , -0.97753012,
#        -0.95892427, -0.70554033, -0.2794155 ,  0.21511999,  0.6569866 ,
#         0.93799998,  0.98935825,  0.79848711,  0.41211849, -0.07515112,
#        -0.54402111, -0.87969576, -0.99999021, -0.87545217, -0.53657292,
#        -0.0663219 ,  0.42016704,  0.80378443,  0.99060736,  0.93489506,
#         0.65028784,  0.20646748, -0.28790332, -0.71178534, -0.96139749,
#        -0.97562601, -0.75098725, -0.34248062,  0.14987721,  0.60553987,
#         0.91294525,  0.99682979,  0.83665564,  0.471639  , -0.00885131,
#        -0.48717451, -0.8462204 , -0.99808203, -0.90557836, -0.59135753,
#        -0.13235175,  0.35905835,  0.76255845,  0.97935764,  0.95637593,
#         0.69924003,  0.27090579, -0.22375564, -0.66363388, -0.94103141,
#        -0.98803162, -0.79312724, -0.40403765,  0.08397446,  0.55142668,
# ...

# %%
plt.plot(time,amplitude)

# %%
plt.plot(amplitude,time)

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sbn

# %%
sbn.set(style ='whitegrid')  #darkgrid,whitegrid,dark,white,ticks

# %%
ran=np.random.randn(1000)

# %%
ran
# Out:
# array([-1.00356895e-01,  9.27176939e-01, -5.47350654e-02, -3.15566779e-01,
#         6.89433481e-01, -1.00799873e+00, -3.40507887e-01,  2.18744189e-02,
#        -3.64117472e-01,  1.84289452e+00, -4.94543735e-01, -1.54620881e+00,
#        -8.01841063e-01, -3.08135898e-01, -9.13593091e-01, -4.63525114e-01,
#        -1.05070391e+00, -7.60900518e-01, -1.29035174e+00, -1.55809257e+00,
#        -1.23191956e+00,  2.14362717e-01,  2.43078815e-01, -4.26845749e-01,
#         1.38907044e+00,  1.26008390e+00, -2.46043500e-01,  6.89783293e-01,
#         1.41756092e+00, -3.35524104e-01,  8.34980751e-03,  5.15838847e-01,
#        -5.69134354e-01, -4.73191442e-01,  8.26477749e-01,  8.19384520e-01,
#        -1.84799033e-01,  4.47361101e-01,  2.06496867e-01, -1.05883292e+00,
#         6.63918272e-02, -1.25173010e+00,  7.75496648e-01, -1.50062925e+00,
#        -2.14194697e+00,  7.37001484e-02, -7.21238123e-01, -2.50751490e+00,
# ...

# %%
sbn.distplot(ran)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1180\1519074523.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(ran)
# <Axes: ylabel='Density'>

# %%
sbn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip=sbn.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.tail()#to view a last rows
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sbn.relplot(x='total_bill',y='tip',data=tip,col="time",hue="day",style="day",kind="line")

# %% [markdown]
# # scatter box plot

# %%
sbn.catplot(x='day',y='total_bill',kind='box',data=tip)

# %% [markdown]
# # Regression plot

# %%
sbn.regplot(x='total_bill',y='tip',data=tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
iris=sbn.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sbn.pairplot(iris,hue='species',palette='Set1')
